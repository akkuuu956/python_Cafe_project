# %%
class PythonCafeTalk:
    def __init__(rp):
        print("\t\t\t\t Python Cafe Talk")
        print("\t\t\t\t Since-1978")
        print("\t\t\t\t www.pythoncafetalk.com")
        print("\n\n\t\t\t\t\t MENU")
        x=["INDIAN","GERMAN","KOREAN","CHINESE"]
        for k in x:
            print("\n\n",k)
            
    def german(rp):
        x=["Beef","Pork","stew","Prones","beef roll"]
        y=[234,453,500,465,980]
        german_={"German Food Types":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(german_)
        print("\n\n german Foods \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("Enter the value position"))
            c=int(input("Enter the Quantity of the selected item:"))
            z=german_["Price"][b]
            y=z*c
            d.append(y)
            x=input("you want to reorder anything(yes/no)")
            if(x=="no"):
                print("Tha(nk you. Please check the amount to be submitted.")
                break
        t=sum(d)
        m=(sum(d)*0.05)
        k=t+m
        print("servicetax=5%")
        print("Total:",t,"Rupees")
        print("Total amount inc. servicetax:",k,"Rupees")
        
    def korean(rp):
        x=["Kimchi Salad","Bibimbap","Bulgogi","Jajangmyeon","Fried chicken"]
        y=[400,350,200,200,265]
        korean_={"Korean Food Item":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(korean_)
        print("\n\n Korean Foods \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("Enter the value position"))
            c=int(input("Enter the Quantity of the selected item:"))
            z=korean_["Price"][b]
            y=z*c
            d.append(y)
            x=input("you want to reorder anything(yes/no)")
            if(x=="no"):
                print("Tha(nk you. Please check the amount to be submitted.")
                break
        t=sum(d)
        m=(sum(d)*0.05)
        k=t+m
        print("servicetax=5%")
        print("Total:",t,"Rupees")
        print("Total amount inc. servicetax:",k,"Rupees")
        
    def chinese(rp):
        x=["Hakka Noodles","Spicy Chilli Noodles","Chinese Hot Pot","Kung Pao Chicken","Wonton Soup"]
        y=[345,345,740,450,345]
        chinese_={"Chinese Food Item":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(chinese_)
        print("\n\n Chinese Food \n\n")    
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("Enter the value position"))
            c=int(input("Enter the Quantity of the selected item:"))
            z=chinese_["Price"][b]
            y=z*c
            d.append(y)
            x=input("you want to reorder anything(yes/no)")
            if(x=="no"):
                print("Tha(nk you. Please check the amount to be submitted.")
                break
        t=sum(d)
        m=(sum(d)*0.05)
        k=t+m
        print("servicetax=5%")
        print("Total:",t,"Rupees")
        print("Total amount inc. servicetax:",k,"Rupees")
        
    def indian(rp):
        x=["Dal Batti Churma","Misal Pav","Pav Bhaji","Vada Pav","Dosa"]
        y=[120,80,80,45,110]
        indian_={"Indian Food Item":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(indian_)
        print("\n\n Indian Foods \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("Enter the value position\n"))
            c=int(input("Enter the Quantity of the selected item:\n"))
            z=indian_["Price"][b]
            y=z*c
            d.append(y)
            x=input("you want to reorder anything(yes/no):\n")
            if(x=="no"):
                print("Thank you. Please check the amount to be submitted.")
                break
        t=sum(d)
        m=(sum(d)*0.05)
        k=t+m
        print("servicetax=5%")
        print("Total:",t,"Rupees")
        print("Total amount inc. servicetax:",k,"Rupees")

# %%
obj=PythonCafeTalk()
x=input("Enter the type of food you want to order")
if x=="german":
    print(obj.german())
elif x=="korean":
    print(obj.korean())
elif x=="chinese":
    print(obj.chinese())
elif x=="indian":
    print(obj.indian())   
else:
    print("Wrong Option: \nPlease choose the right option. thank you ")
# Out:
# 				 Python Cafe Talk
# 				 Since-1978
# 				 www.pythoncafetalk.com
#
#
# 					 MENU
#
#
#  INDIAN
#
#
#  GERMAN
#
#
#  KOREAN
#
#
#  CHINESE
# Enter the type of food you want to orderindian
#
#
#  Indian Foods
#
#
#    Indian Food Item  Price
# 0  Dal Batti Churma    120
# 1         Misal Pav     80
# 2         Pav Bhaji     80
# 3          Vada Pav     45
# 4              Dosa    110
# Enter the value position
# 1
# Enter the Quantity of the selected item:
# 2
# you want to reorder anything(yes/no):
# yes
# Enter the value position
# 2
# Enter the Quantity of the selected item:
# 1
# you want to reorder anything(yes/no):
# no
# Thank you. Please check the amount to be submitted.
# servicetax=5%
# Total: 240 Rupees
# Total amount inc. servicetax: 252.0 Rupees
# None
